# %%
# import libraries
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

# %%
# get dataset
ds = pd.read_csv("Mall_Customers.csv")
X = ds.iloc[:, [3,4]].values

# %%
# Employ the elbow method 
from sklearn.cluster import KMeans
scores = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 42)
    kmeans.fit(X)
    scores.append(kmeans.inertia_)
print(scores)
# Out:
# [269981.28, 183653.3289473684, 106348.37306211119, 73880.64496247195, 44448.45544793371, 40825.16946386946, 33642.579220779226, 26686.83778518778, 24766.471609793443, 23103.122085983916]
# C:\Users\yohan\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\yohan\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# ...

# %%
# WCSS vs no. of clusters plot 
plt.plot(range(1, 11), scores, 'b-')
plt.title("WCSS vs Number of Clusters")
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.show()

# %%
# Training K-Means model 
cluster = KMeans(n_clusters=5, init = 'k-means++', random_state=42)
Ykmeans = cluster.fit_predict(X)
print(X)
print(Ykmeans.reshape(-1,1))
# Out:
# [[ 15  39]
#  [ 15  81]
#  [ 16   6]
#  [ 16  77]
#  [ 17  40]
#  [ 17  76]
#  [ 18   6]
#  [ 18  94]
#  [ 19   3]
#  [ 19  72]
#  [ 19  14]
#  [ 19  99]
#  [ 20  15]
#  [ 20  77]
#  [ 20  13]
#  [ 20  79]
#  [ 21  35]
#  [ 21  66]
#  [ 23  29]
#  [ 23  98]
#  [ 24  35]
#  [ 24  73]
#  [ 25   5]
#  [ 25  73]
#  [ 28  14]
#  [ 28  82]
#  [ 28  32]
#  [ 28  61]
#  [ 29  31]
#  [ 29  87]
#  [ 30   4]
#  [ 30  73]
#  [ 33   4]
#  [ 33  92]
#  [ 33  14]
#  [ 33  81]
#  [ 34  17]
#  [ 34  73]
#  [ 37  26]
#  [ 37  75]
#  [ 38  35]
#  [ 38  92]
#  [ 39  36]
#  [ 39  61]
#  [ 39  28]
#  [ 39  65]
#  [ 40  55]
#  [ 40  47]
#  [ 40  42]
#  [ 40  42]
#  [ 42  52]
#  [ 42  60]
#  [ 43  54]
#  [ 43  60]
#  [ 43  45]
#  [ 43  41]
#  [ 44  50]
#  [ 44  46]
#  [ 46  51]
#  [ 46  46]
#  [ 46  56]
#  [ 46  55]
#  [ 47  52]
#  [ 47  59]
#  [ 48  51]
#  [ 48  59]
#  [ 48  50]
#  [ 48  48]
#  [ 48  59]
#  [ 48  47]
#  [ 49  55]
#  [ 49  42]
#  [ 50  49]
#  [ 50  56]
#  [ 54  47]
#  [ 54  54]
# ...

# %%
# Visualizing the clusters
plt.scatter(X[Ykmeans == 0, 0], X[Ykmeans == 0, 1], s=100, c='red', label = 'cluster 1')
plt.scatter(X[Ykmeans == 1, 0], X[Ykmeans == 1, 1], s=100, c='blue', label = 'cluster 2')
plt.scatter(X[Ykmeans == 2, 0], X[Ykmeans == 2, 1], s=100, c='green', label = 'cluster 3')
plt.scatter(X[Ykmeans == 3, 0], X[Ykmeans == 3, 1], s=100, c='yellow', label = 'cluster 4')
plt.scatter(X[Ykmeans == 4, 0], X[Ykmeans == 4, 1], s=100, c='pink', label = 'cluster 5')
plt.scatter(cluster.cluster_centers_[:, 0], cluster.cluster_centers_[:, 1], s=300, c = 'black', label = 'Centroids', marker='+')
plt.title('Clusters')
plt.xlabel('Income')
plt.ylabel('Spending Score')
plt.legend()
plt.show()
print(cluster.cluster_centers_)
# Out:
# [[55.2962963  49.51851852]
#  [86.53846154 82.12820513]
#  [25.72727273 79.36363636]
#  [88.2        17.11428571]
#  [26.30434783 20.91304348]]
